# %% [markdown]
# # Canary Rollout\n\n**Created by School of AI**

# %%
import sys\nfrom pathlib import Path\nsys.path.append(str(Path.cwd().parent/"src"))\nfrom devops_engineering.deployment import canary_split,rollout_decision\nprint(canary_split(100,10));print(rollout_decision(.004,180,.01,250))
