# %% [markdown]
# # Semantic Versioning\n\n**Created by School of AI**

# %%
import sys\nfrom pathlib import Path\nsys.path.append(str(Path.cwd().parent/"src"))\nfrom devops_engineering.semver import bump\nprint(bump("1.2.3","patch"));print(bump("1.2.3","minor"))
